# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive/') # this makes your Drive appear in 'content' folder
product_df=pd.read_csv("/content/drive/MyDrive/bttai_accenture/Data Cleaning/rongzi/Data/product_info_clean.csv")
rev_df=pd.read_csv("/content/drive/MyDrive/bttai_accenture/Data Cleaning/sofia/reviews_clean_1.csv")
review_df=rev_df.drop(labels=["review_text","review_title","price_usd",'brand_name',"product_name","submission_time","skin_tone","eye_color"],axis=1)
review_df.dropna(inplace=True)
combined_data = review_df.merge(product_df,how="left",on="product_id")
print(combined_data.columns)
print(len(combined_data))
# Out:
# Mounted at /content/drive/
# <ipython-input-1-d395a3eea1b7>:9: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   rev_df=pd.read_csv("/content/drive/MyDrive/bttai_accenture/Data Cleaning/sofia/reviews_clean_1.csv")
# Index(['skin_tone_quartile_num', 'Unnamed: 1', 'Unnamed: 0', 'author_id',
#        'rating_x', 'is_recommended', 'helpfulness', 'total_feedback_count',
#        'total_neg_feedback_count', 'total_pos_feedback_count', 'skin_type',
#        'hair_color', 'product_id', 'skin_tone_num', 'eye_color_num',
#        'skin_type_num', 'hair_color_num', 'review_text_processed',
#        'nltk_analysis', 'skin_tone_quartile_num.1', 'product_name', 'brand_id',
#        'brand_name', 'loves_count', 'rating_y', 'reviews', 'limited_edition',
#        'new', 'online_only', 'out_of_stock', 'sephora_exclusive', 'Award',
#        'Clean at Sephora', 'combined_category_Bath & Body',
# ...

# %%
print(combined_data["nltk_analysis"].head())
# Out:
# 0    {'neg': 0.061, 'neu': 0.49, 'pos': 0.449, 'com...
# 1    {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'comp...
# 2    {'neg': 0.0, 'neu': 0.413, 'pos': 0.587, 'comp...
# 3    {'neg': 0.0, 'neu': 0.524, 'pos': 0.476, 'comp...
# 4    {'neg': 0.0, 'neu': 0.63, 'pos': 0.37, 'compou...
# Name: nltk_analysis, dtype: object

# %%
#combined_data=combined_data.drop(labels=["product_name","brand_name","brand_id"],axis=1)
combined_data.to_csv('/content/drive/MyDrive/bttai_accenture/Data Cleaning/rongzi/test.csv', index=True)
